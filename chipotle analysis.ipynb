# %%
# Chipotle.tsv data

# %%
import pandas as pd
import numpy as np

# %%
pd.read_table('https://raw.githubusercontent.com//justmarkham//DAT8//master//data//chipotle.tsv')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data_chip =pd.read_table('https://raw.githubusercontent.com//justmarkham//DAT8//master//data//chipotle.tsv')

# %%
data_chip
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# calculating total price for items

# %%
data_chip.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
data_chip.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data_chip['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
data_chip['item_price_$rem'] = data_chip['item_price'].str.replace('$','')

# %%
data_chip['item_price_$rem'] = data_chip['item_price'].str.strip('$')

# %%
data_chip['item_price_$rem']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price_$rem, Length: 4622, dtype: object

# %%
data_chip['item_price_$rem'].astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price_$rem, Length: 4622, dtype: float64

# %%
data_chip['item_price_$rem']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price_$rem, Length: 4622, dtype: object

# %%
data_chip['item_price_$rem'] = data_chip['item_price_$rem'].map(lambda x :float(x))

# %%
data_chip['item_price_$rem'].dtypes
# Out:
# dtype('float64')

# %%
data_chip.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_$rem
# 0             2.39
# 1             3.39
# 2             3.39
# 3             2.39
# 4            16.98

# %%
data_chip['Tot_price'] = data_chip['quantity'] * data_chip['item_price_$rem']

# %%
data_chip.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_$rem  Tot_price
# 0             2.39       2.39
# 1             3.39       3.39
# 2             3.39       3.39
# 3             2.39       2.39
# 4            16.98      33.96

# %%
data_chip.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#       item_price_$rem  Tot_price
# 4617            11.75      11.75
# 4618            11.75      11.75
# 4619            11.25      11.25
# 4620             8.75       8.75
# 4621             8.75       8.75

# %%
data_chip.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price             object
# item_price_$rem       float64
# Tot_price             float64
# dtype: object

# %%
data_chip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 7 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# item_price_$rem       4622 non-null float64
# Tot_price             4622 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 252.9+ KB

# %%
data_chip.shape
# Out:
# (4622, 7)

# %%
# print name of all columnes

# %%
data_chip.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'item_price_$rem', 'Tot_price'],
#       dtype='object')

# %%
# how is data set indexed
data_chip.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# which is most ordered item. how many items were ordered

# %%
c = data_chip.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'] , ascending= False)
c
# Out:
#                                        order_id  quantity  item_price_$rem  \
# item_name
# Chicken Bowl                             713926       761          7342.73
# Chicken Burrito                          497303       591          5575.82
# Chips and Guacamole                      449959       506          2201.04
# Steak Burrito                            328437       386          3851.43
# Canned Soft Drink                        304753       351           438.75
# Chips                                    208004       230           494.34
# Steak Bowl                               193752       221          2260.19
# Bottled Water                            175944       211           302.56
# Chips and Fresh Tomato Salsa             100419       130           361.36
# Canned Soda                               76396       126           137.34
# Chicken Salad Bowl                       117104       123          1228.75
# ...

# %%
c.head()
# Out:
#                      order_id  quantity  item_price_$rem  Tot_price
# item_name
# Chicken Bowl           713926       761          7342.73    8044.63
# Chicken Burrito        497303       591          5575.82    6387.06
# Chips and Guacamole    449959       506          2201.04    2475.62
# Steak Burrito          328437       386          3851.43    4236.13
# Canned Soft Drink      304753       351           438.75     603.75

# %%
# most ordered item in the choice description column

# %%
d = data_chip.groupby('choice_description')
d = d.sum()
d = d.sort_values(['quantity'], ascending = False)
d
# Out:
#                                                     order_id  quantity  \
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
# ...                                                      ...       ...
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...       577         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...       585         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...       235         1
# [Roasted Chili Corn Salsa, [Guacamole, Sour Cre...       987         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1299         1
#
#                                                     item_price_$rem  Tot_price
# ...

# %%
d.head(1)
# Out:
#                     order_id  quantity  item_price_$rem  Tot_price
# choice_description
# [Diet Coke]           123455       159           326.71     408.41

# %%
# how much was the revenue for the period in the dataset

# %%
revenue = (data_chip["quantity"] * data_chip['item_price_$rem']).sum()

# %%
revenue = print('Revenue was : $'+ str(np.round(revenue,2)))
# Out:
# Revenue was : $39237.02

# %%
# print the datafram with only 2 column - item name  and item price

# %%
data_chip_itname_itprice = data_chip.drop_duplicates(['item_name'])

# %%
data_chip_itname_itprice
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 18           9         2                            Canned Soda
# 21          11         1                       Barbacoa Burrito
# ...

# %%
data_chip_itname_itprice = data_chip_itname_itprice.sort_values('item_name')

# %%
data_chip_itname_itprice.head(10)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
#
#                                    choice_description item_price  \
# 0                                                 NaN     $2.39
# 1                                        [Clementine]     $3.39
# 2                                             [Apple]     $3.39
# ...

# %%
two_column = data_chip_itname_itprice[['item_name','item_price']]

# %%
two_column
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# 6                             Side of Chips     $1.69
# 7                             Steak Burrito    $11.75
# 8                          Steak Soft Tacos     $9.25
# 10                      Chips and Guacamole     $4.45
# 11                     Chicken Crispy Tacos     $8.75
# 12                       Chicken Soft Tacos     $8.75
# 16                          Chicken Burrito     $8.49
# 18                              Canned Soda     $2.18
# 21                         Barbacoa Burrito     $8.99
# 27                         Carnitas Burrito     $8.99
# 33                            Carnitas Bowl     $8.99
# ...

# %%
# delete the duplicates in item_name and quantity
filtered = data_chip.drop_duplicates(['item_name','quantity'])

# %%
filtered.sort_values('item_name')
# Out:
#       order_id  quantity              item_name  \
# 298        129         1      6 Pack Soft Drink
# 3389      1360         2      6 Pack Soft Drink
# 39          19         1          Barbacoa Bowl
# 21          11         1       Barbacoa Burrito
# 1903       768         2  Barbacoa Crispy Tacos
# ...        ...       ...                    ...
# 1653       668         1    Veggie Crispy Tacos
# 1694       686         1           Veggie Salad
# 186         83         1      Veggie Salad Bowl
# 3889      1559         2      Veggie Soft Tacos
# 738        304         1      Veggie Soft Tacos
#
#                                      choice_description item_price  \
# 298                                            [Sprite]     $6.49
# 3389                                        [Diet Coke]    $12.98
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.75
# 21    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# ...

# %%
# select only product with quantity equal to 1

# %%
quantiy1 = filtered[filtered.quantity == 1]

# %%
quantiy1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
# select only item name and item price column

# %%
price_per_item = data_chip[['item_name','item_price']]

# %%
price_per_item
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
price_per_item = quantiy1[['item_name','item_price']]

# %%
price_per_item.sort_values(by='item_price', ascending= False)
# Out:
#                                   item_name item_price
# 92                       Steak Crispy Tacos     $9.25
# 554                   Carnitas Crispy Tacos     $9.25
# 237                     Carnitas Soft Tacos     $9.25
# 56                      Barbacoa Soft Tacos     $9.25
# 8                          Steak Soft Tacos     $9.25
# 21                         Barbacoa Burrito     $8.99
# 664                             Steak Salad     $8.99
# 54                               Steak Bowl     $8.99
# 33                            Carnitas Bowl     $8.99
# 27                         Carnitas Burrito     $8.99
# 3750                         Carnitas Salad     $8.99
# 12                       Chicken Soft Tacos     $8.75
# 11                     Chicken Crispy Tacos     $8.75
# 44                       Chicken Salad Bowl     $8.75
# 16                          Chicken Burrito     $8.49
# 1694                           Veggie Salad     $8.49
# ...

# %%
#sort the value from most to least expensive

# %%
price_per_item.sort_values(by="item_price", ascending = False)
# Out:
#                                   item_name item_price
# 92                       Steak Crispy Tacos     $9.25
# 554                   Carnitas Crispy Tacos     $9.25
# 237                     Carnitas Soft Tacos     $9.25
# 56                      Barbacoa Soft Tacos     $9.25
# 8                          Steak Soft Tacos     $9.25
# 21                         Barbacoa Burrito     $8.99
# 664                             Steak Salad     $8.99
# 54                               Steak Bowl     $8.99
# 33                            Carnitas Bowl     $8.99
# 27                         Carnitas Burrito     $8.99
# 3750                         Carnitas Salad     $8.99
# 12                       Chicken Soft Tacos     $8.75
# 11                     Chicken Crispy Tacos     $8.75
# 44                       Chicken Salad Bowl     $8.75
# 16                          Chicken Burrito     $8.49
# 1694                           Veggie Salad     $8.49
# ...

# %%
# what was quantity of the most expensive item

# %%
d = data_chip.groupby('choice_description')
d = d.sum()
d = d.sort_values(['quantity'], ascending = False)
d

# %%
most_expensive = data_chip.sort_values(['item_price'], ascending= False)

# %%
most_expensive = most_expensive.sort_values(by='item_price',ascending= False).head(1)

# %%
most_expensive
# Out:
#       order_id  quantity         item_name  \
# 2624      1042         1  Steak Salad Bowl
#
#                                      choice_description item_price  \
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39
#
#       item_price_$rem  Tot_price
# 2624             9.39       9.39

# %%
# how many time veggie salad bowl ordered

# %%
data_veggie = data_chip[data_chip.item_name == 'Veggie Salad Bowl']

# %%
data_veggie
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description item_price
# ...
